# %% [markdown]
# # Supervised Machine learning

# %%
import pandas as pd

# %% [markdown]
# ### loading the file

# %%
file= r"C:\Users\HP 440 G3\Downloads\Used_Bikes.csv"

# %% [markdown]
# ### reading the file data

# %%
df=pd.read_csv(file)

# %%
df
# Out:
#                                   bike_name   price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1               Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                      Triumph Daytona 675R  600000      Delhi         110
# 3                      TVS Apache RTR 180cc   65000  Bangalore       16329
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                     ...     ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000      Delhi       22000
# 32644                  TVS Apache RTR 180cc   30000     Karnal        6639
# 32645              Bajaj Avenger Street 220   60000      Delhi       20373
# 32646             Hero Super Splendor 125cc   15600     Jaipur       84186
# 32647                    Bajaj Pulsar 150cc   22000       Pune       60857
#
#              owner  age  power          brand
# ...

# %%
df['owner']
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4        First Owner
#             ...
# 32643    First Owner
# 32644    First Owner
# 32645    First Owner
# 32646    First Owner
# 32647    First Owner
# Name: owner, Length: 32648, dtype: object

# %%
daat={"First Owner":1, "Second Owner":2, "Third Owner":3, 'Fourth Owner':4}
daat
# Out:
# {'First Owner': 1, 'Second Owner': 2, 'Third Owner': 3, 'Fourth Owner': 4}

# %%
df['owner']=df['owner'].map(daat)

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
buu=df[(df['brand']=='TVS')|(df['brand']=='Yamaha')|(df['brand']=='Hero')|(df['brand']=='Bajaj')|(df['brand']=='royal Enfield')|(df['brand']=='Jawa')|(df['brand']=='BMW')|(df['brand']=='Kawasaki')|(df['brand']=='Suzuki')|(df['brand']=='Benelli')|(df['brand']=='Mahindra')|(df['brand']=='Harley-Davidson')|(df['brand']== 'Ducati')|(df['brand']== 'Suzuki')|(df['brand']=='Hyosung') |(df['brand']=='honda') ]

# %%
buu
# Out:
#                                   bike_name  price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc  35000  Ahmedabad       17654
# 3                      TVS Apache RTR 180cc  65000  Bangalore       16329
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition  80000  Bangalore       10000
# 5                          Yamaha FZs 150cc  53499      Delhi       25000
# 7       Hero Splendor Plus Self Alloy 100cc  45000      Delhi       12645
# ...                                     ...    ...        ...         ...
# 32643                Hero Passion Pro 100cc  39000      Delhi       22000
# 32644                  TVS Apache RTR 180cc  30000     Karnal        6639
# 32645              Bajaj Avenger Street 220  60000      Delhi       20373
# 32646             Hero Super Splendor 125cc  15600     Jaipur       84186
# 32647                    Bajaj Pulsar 150cc  22000       Pune       60857
#
#        owner  age  power   brand
# 0        1.0    3    110     TVS
# ...

# %% [markdown]
# ### dropping the duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
buu=df[(df['brand']=='TVS')|(df['brand']=='Yamaha')|(df['brand']=='Hero')|(df['brand']=='Bajaj')|(df['brand']=='royal Enfield')|(df['brand']=='Jawa')|(df['brand']=='BMW')|(df['brand']=='Kawasaki')|(df['brand']=='Suzuki')|(df['brand']=='Benelli')|(df['brand']=='Mahindra')|(df['brand']=='Harley-Davidson')|(df['brand']== 'Ducati')|(df['brand']== 'Suzuki')|(df['brand']=='Hyosung') |(df['brand']=='honda') ]

# %%
buu
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# 5                         Yamaha FZs 150cc   53499      Delhi       25000
# 7      Hero Splendor Plus Self Alloy 100cc   45000      Delhi       12645
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#       owner  age  power            brand
# ...

# %%
brand_ls = list(df['brand'].value_counts().head(16).keys())
brand_ls
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df5=df[df['brand'].isin(brand_ls)]

# %%
df5
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#       owner  age  power            brand
# ...

# %% [markdown]
# ### mapping bike_names with a number

# %%
dictionar= {
    'Bajaj': 1,'Royal Enfield': 2,'Hero': 3,'Honda': 4,'Yamaha': 5,'TVS': 6,'KTM': 7,'Suzuki': 8,'Harley-Davidson': 9,'Kawasaki': 10,'Hyosung': 11,
    'Mahindra': 12,
    'Benelli': 13,
    'Triumph': 14,
    'Ducati': 15,
    'BMW': 16
}


df5['brand'] = df5['brand'].map(dictionar)
# Out:
# C:\Users\HP 440 G3\AppData\Local\Temp\ipykernel_6948\3697615929.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['brand'] = df5['brand'].map(dictionar)

# %%
df5
# Out:
#                                  bike_name   price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000  Ahmedabad       17654
# 1              Royal Enfield Classic 350cc  119900      Delhi       11000
# 2                     Triumph Daytona 675R  600000      Delhi         110
# 3                     TVS Apache RTR 180cc   65000  Bangalore       16329
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000  Bangalore       10000
# ...                                    ...     ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000      Delhi       48587
# 9369                   Bajaj Avenger 220cc   35000  Bangalore       60000
# 9370        Harley-Davidson Street 750 ABS  450000    Jodhpur        3430
# 9371                 Bajaj Dominar 400 ABS  139000  Hyderabad       21300
# 9372              Bajaj Avenger Street 220   80000  Hyderabad        7127
#
#       owner  age  power  brand
# 0       1.0    3    110      6
# ...

# %% [markdown]
# ##### dropping the columns which are not numerical

# %%
df5.drop(['bike_name','city'],inplace=True,axis=1)
# Out:
# C:\Users\HP 440 G3\AppData\Local\Temp\ipykernel_6948\2361103910.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.drop(['bike_name','city'],inplace=True,axis=1)

# %%
df5.head()
# Out:
#     price  kms_driven  owner  age  power  brand
# 0   35000       17654    1.0    3    110      6
# 1  119900       11000    1.0    4    350      2
# 2  600000         110    1.0    8    675     14
# 3   65000       16329    1.0    4    180      6
# 4   80000       10000    1.0    3    150      5

# %% [markdown]
# ### checking for null values

# %%
df5.isnull().sum()
# Out:
# price          0
# kms_driven     0
# owner         10
# age            0
# power          0
# brand          0
# dtype: int64

# %% [markdown]
# ### dropping the null values

# %%
df5.dropna(inplace=True)
# Out:
# C:\Users\HP 440 G3\AppData\Local\Temp\ipykernel_6948\4279374786.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.dropna(inplace=True)

# %%
df5.isnull().sum()
# Out:
# price         0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df5.drop_duplicates(inplace=True)
# Out:
# C:\Users\HP 440 G3\AppData\Local\Temp\ipykernel_6948\895407579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5.drop_duplicates(inplace=True)

# %%
x=df5.drop('price',axis=1)

# %%
x
# Out:
#       kms_driven  owner  age  power  brand
# 0          17654    1.0    3    110      6
# 1          11000    1.0    4    350      2
# 2            110    1.0    8    675     14
# 3          16329    1.0    4    180      6
# 4          10000    1.0    3    150      5
# ...          ...    ...  ...    ...    ...
# 9362       48587    1.0    8    150      3
# 9369       60000    1.0    9    220      1
# 9370        3430    1.0    4    750      9
# 9371       21300    1.0    4    400      1
# 9372        7127    1.0    5    220      1
#
# [7279 rows x 5 columns]

# %%
x.duplicated().sum()
# Out:
# 441

# %% [markdown]
# #### target/dependent variable

# %%
y=df5[['price']]

# %%
y.shape
# Out:
# (7279, 1)

# %% [markdown]
# #### independent variable

# %%
x.shape
# Out:
# (7279, 5)

# %% [markdown]
# ## training the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## linear regression algorithm

# %%
from sklearn.linear_model import LinearRegression

# %%
lnr=LinearRegression() # object creation

# %%
x_train.shape
# Out:
# (5823, 5)

# %%
x_train
# Out:
#       kms_driven  owner  age  power  brand
# 2218       10000    1.0   16    100      3
# 6344        6000    1.0    3    100      1
# 8273       47970    1.0   16    150      1
# 8050       71124    1.0    8    200      1
# 4680        4178    2.0   10    350      2
# ...          ...    ...  ...    ...    ...
# 8988       50000    1.0   11    100      1
# 891        49660    1.0   12    100      3
# 8277       40000    2.0   17    350      2
# 7290       38057    1.0    7    150      5
# 9156       38000    1.0   11    100      3
#
# [5823 rows x 5 columns]

# %%
lnr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### checking the accuracy

# %%
lnr.score(x_test,y_test)*100
# Out:
# 76.16494826454505

# %%
lnr.score(x_train,y_train)*100
# Out:
# 73.49563175064502

# %% [markdown]
# ### Prediction

# %%
prediction=lnr.predict(x_test)

# %%
y_test['prediction']=prediction

# %%
y_test.head(40)
# Out:
#        price     prediction
# 3160  170000  222147.647772
# 9274  511000  503039.036510
# 1585   39900   33000.986763
# 5267   20000   -2186.645414
# 7889   80000   52861.275559
# 2158  150000  207179.340214
# 9010   99500  132017.965470
# 6824   65000   56029.339779
# 6988   65000  110450.325898
# 1904   31500    6945.579011
# 1558  113000  215783.494493
# 198   140000  141355.457650
# 5922   78000  131563.195518
# 6189   51000   54881.378790
# 4573   65000   38164.360837
# 1513   58000   55277.980492
# 7270   19000   -3721.759152
# 1762   89135   95204.219630
# 3177   35000   32217.683034
# 6273   22000   -9091.766063
# 2550  130000  221963.165838
# 1054   85000   51310.142871
# 8066   75000  117612.903924
# 355    42000   60570.445164
# 7573  106000  141689.438031
# 5567   85000   91441.156286
# 7598   22500   57541.514513
# 7548   12000  -32435.178918
# 43    110000   65481.734286
# 6115   46000  107423.954444
# 2802   46000   16848.007237
# 7888   60000   49679.198920
# ...

# %% [markdown]
# ### saving the model

# %%
import os,joblib

# %%
os.makedirs('models',exist_ok=True)

# %%
lnr
# Out:
# LinearRegression()

# %%
joblib.dump(lnr,"./models/linear_model.lb")
# Out:
# ['./models/linear_model.lb']

# %% [markdown]
# # End of the project
